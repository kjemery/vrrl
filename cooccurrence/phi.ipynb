# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
cooccur = pd.read_csv('cooccur.csv',index_col=0)

# %%
def phi(coccur,edge=[object1,object2]):
# Out:
# 0.021394107616132432

# %%
edge = ['clipboard','baking_oven']
tt = cooccur[edge[0]][edge[1]] / np.sum()

# %%
cooccur[edge[0]]
# Out:
# 0
# clipboard         1.000000
# baking_oven       0.035955
# bar_stool         0.215839
# basket            0.155844
# blender           0.133688
#                     ...
# trash_can         0.231149
# tub               0.015901
# vanity_case       0.197691
# wash_cloth        0.036936
# window_curtain    0.165682
# Name: clipboard, Length: 98, dtype: float64

# %%
cooccur
# Out:
#                 clipboard  baking_oven  bar_stool    basket   blender  \
# 0
# clipboard        1.000000     0.035955   0.215839  0.155844  0.133688
# baking_oven      0.035955     1.000000   0.315146  0.234592  0.336647
# bar_stool        0.215839     0.315146   1.000000  0.171352  0.133688
# basket           0.155844     0.234592   0.171352  1.000000  0.106206
# blender          0.133688     0.336647   0.133688  0.106206  1.000000
# ...                   ...          ...        ...       ...       ...
# trash_can        0.231149     0.156744   0.198200  0.342098  0.188367
# tub              0.015901     0.314694   0.362650  0.306818  0.257300
# vanity_case      0.197691     0.196686   0.243033  0.193980  0.167066
# wash_cloth       0.036936     0.377635   0.239961  0.174784  0.165946
# window_curtain   0.165682     0.438385   0.455145  0.144854  0.101289
#
#                 bread_maker  cabinets       can  can_opener    candle  ...  \
# ...
